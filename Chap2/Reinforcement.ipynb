# %% [markdown]
# Give three examples of life-critical software applications.

# %% [markdown]
# #R-2.1
#
# 1. Air Traffic Control Systems: Air traffic control systems are responsible for managing and directing aircraft in the air and on the ground. These systems help ensure the safety of passengers, aircraft, and personnel by ensuring proper communication, navigation, and surveillance of airspace.
#
# 2. Hospital Management Systems: Hospital management systems are responsible for managing patient data, scheduling appointments, and managing medical records. They help streamline the medical process to ensure patient safety and the quality of care.
#
# 3. Automated Manufacturing Systems: Automated manufacturing systems are responsible for controlling and monitoring the production of goods. These systems help ensure the accuracy and efficiency of production, while also providing safety features that can prevent accidents and hazardous situations.

# %% [markdown]
# Give an example of a software application in which adaptability can mean
# the difference between a prolonged lifetime of sales and bankruptcy.

# %% [markdown]
# #R-2.2
#
# A good example of a software application where adaptability can mean the difference between success and failure is an e-commerce platform. As new technologies become available, as customers' tastes and preferences change, and as new competitors enter the market, a successful e-commerce platform must be able to quickly adapt to these changes and stay ahead of the competition. If an e-commerce platform is not able to keep up with the latest trends, it may lose customers and market share, leading to decreased sales and eventually bankruptcy.

# %% [markdown]
# Describe a component from a text-editor GUI and the methods that it encapsulates

# %% [markdown]
# #R-2.3
#
# A text editor GUI component that is commonly included is a toolbar. A toolbar typically includes basic text formatting options such as bold, italics, underline, font size, and font type. It also may include options for formatting text alignment, inserting images, and creating tables. The methods that the toolbar encapsulates are commands to execute the formatting changes and operations, such as setting the font size, changing the color of the text, and inserting images or tables.

# %% [markdown]
# Write a Python class, Flower, that has three instance variables of type str,
# int, and float, that respectively represent the name of the flower, its number of petals, and its price. Your class must include a constructor method
# that initializes each variable to an appropriate value, and your class should
# include methods for setting the value of each type, and retrieving the value
# of each type.

# %%
#R-2.4

class Flower():
    def __init__(self, name, petals, price):
        self.name = name
        self.petals = petals
        self.price = price

    def set_name(self, name):
        self.name = name

    def get_name(self):
        return self.name

    def set_petals(self, petals):
        self.petals = petals

    def get_petals(self):
        return self.petals

    def set_price(self, price):
        self.price = price

    def get_price(self):
        return self.price

# %% [markdown]
# Use the techniques of Section 1.7 to revise the charge and make payment
# methods of the CreditCard class to ensure that the caller sends a number
# as a parameter.

# %%
#R-2.5

# Revised CreditCard class
class CreditCard:
    """A consumer credit card."""

    def __init__(self, customer, bank, acnt, limit, balance=0):
        """ Create a new credit card instance.
        The initial balance is zero.
        
        customer    the name of the customer (e.g., John Bowman )
        bank        the name of the bank (e.g., California Savings )
        acnt        the acount identifier (e.g., 5391 0375 9387 5309 )
        limit       credit limit (measured in dollars)
        """
        self._customer = customer
        self._bank = bank
        self._account = acnt
        self._limit = limit
        self._balance = balance

    def get_customer(self):
        """Return name of the customer."""
        return self._customer

    def get_bank(self):
        """Return the bank's name."""
        return self._bank

    def get_account(self):
        """Return the card identifying number (typically stored as a string)."""
        return self._account

    def get_limit(self):
        """Return current credit limit."""
        return self._limit

    def get_balance(self):
        """Return current balance."""
        return self._balance

    def charge(self, price):
        """Charge given price to the card, assuming sufficient credit limit.
        Return True if charge was processed; False if charge was denied.
        """
        if type(price) != int:
            raise TypeError("Price must be a number")
        if price + self._balance > self._limit:  # if charge would exceed limit,
            return False  # cannot accept charge
        else:
            self._balance += price
            return True

    def make_payment(self, amount):
        """Process customer payment that reduces balance.
        Parameters:
            amount (int) = The amount to be paid by the customer
        """
        if type(amount) != int:
            raise TypeError("Amount must be a number")
        if amount < 0:
            raise ValueError("Amount must be nonnegative")
        self._balance -= amount

# %% [markdown]
# If the parameter to the make payment method of the CreditCard class
# were a negative number, that would have the effect of raising the balance
# on the account. Revise the implementation so that it raises a ValueError if
# a negative value is sent

# %%
#R-2.6

class CreditCard:
    def __init__(self, customer, bank, acnt, limit):
        self._customer = customer
        self._bank = bank
        self._account = acnt
        self._limit = limit
        self._balance = 0

    def get_customer(self):
        return self._customer

    def get_bank(self):
        return self._bank

    def get_account(self):
        return self._account

    def get_limit(self):
        return self._limit

    def get_balance(self):
        return self._balance

    def charge(self, price):
        if price + self._balance > self._limit:
            return False
        else:
            self._balance += price
            return True

    def make_payment(self, amount):
        if amount < 0:
            raise ValueError('Cannot process negative payment.')
        else:
            self._balance -= amount

# %% [markdown]
# The CreditCard class of Section 2.3 initializes the balance of a new account to zero. Modify that class so that a new account can be given a
# nonzero balance using an optional fifth parameter to the constructor. The
# four-parameter constructor syntax should continue to produce an account
# with zero balance.

# %%
#R-2.7

class CreditCard:
    def __init__(self, customer, bank, acnt, limit, balance):
        self._customer = customer
        self._bank = bank
        self._account = acnt
        self._limit = limit
        self._balance = balance

    def get_customer(self):
        return self._customer

    def get_bank(self):
        return self._bank

    def get_account(self):
        return self._account

    def get_limit(self):
        return self._limit

    def get_balance(self):
        return self._balance

    def charge(self, price):
        if price + self._balance > self._limit:
            return False
        else:
            self._balance += price
            return True

    def make_payment(self, amount):
        self._balance -= amount

# %% [markdown]
#  Modify the declaration of the first for loop in the CreditCard tests, from
# Code Fragment 2.3, so that it will eventually cause exactly one of the three
# credit cards to go over its credit limit. Which credit card is it?

# %% [markdown]
# #R-2.8
# It was the credit card from California Savings.

# %% [markdown]
# Implement the sub method for the Vector class of Section 2.3.3, so
# that the expression u−v returns a new vector instance representing the
# difference between two vectors.

# %%
#R-2.9

class Vector:
    """Represent a vector in a multidimensional space."""

    def __init__(self, d):
        """Create d-dimensional vector of zeros."""
        self._coords = [0] * d

    def __len__(self):
        """Return the dimension of the vector."""
        return len(self._coords)

    def __getitem__(self, j):
        """Return jth coordinate of vector."""
        return self._coords[j]

    def __setitem__(self, j, val):
        """Set jth coordinate of vector to given value."""
        self._coords[j] = val

    def __add__(self, other):
        """Return sum of two vectors."""
        if len(self) != len(other):
            # relies on len method
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] + other[j]
        return result

    def __sub__(self, other):
        """Return difference of two vectors."""
        if len(self) != len(other):
            # relies on len method
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] - other[j]
        return result

    def __eq__(self, other):
        """Return True if vector has same coordinates as other."""
        return self._coords == other._coords

    def __ne__(self, other):
        """Return True if vector differs from other."""
        return not self == other            # rely on existing __eq__ definition

    def __str__(self):
        """Produce string representation of vector."""
        return '<' + str(self._coords)[1:-1] + '>'  # adapt list representation

# %% [markdown]
# Implement the neg method for the Vector class of Section 2.3.3, so
# that the expression −v returns a new vector instance whose coordinates
# are all the negated values of the respective coordinates of v

# %%
#R-2.10

class Vector:
    """Represent a vector in a multidimensional space."""

    def __init__(self, d):
        """Create d-dimensional vector of zeros."""
        self._coords = [0] * d

    def __len__(self):
        """Return the dimension of the vector."""
        return len(self._coords)

    def __getitem__(self, j):
        """Return jth coordinate of vector."""
        return self._coords[j]

    def __setitem__(self, j, val):
        """Set jth coordinate of vector to given value."""
        self._coords[j] = val

    def __add__(self, other):
        """Return sum of two vectors."""
        if len(self) != len(other):
            # relies on len method
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] + other[j]
        return result

    def __sub__(self, other):
        """Return difference of two vectors."""
        if len(self) != len(other):
            # relies on len method
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] - other[j]
        return result

    def __neg__(self):
        """Return the negation of a vector"""
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = -self[j]
        return result

    def __eq__(self, other):
        """Return True if vector has same coordinates as other."""
        return self._coords == other._coords

    def __ne__(self, other):
        """Return True if vector differs from other."""
        return not self == other            # rely on existing __eq__ definition

    def __str__(self):
        """Produce string representation of vector."""
        return '<' + str(self._coords)[1:-1] + '>'  # adapt list representation

# %% [markdown]
# In Section 2.3.3, we note that our Vector class supports a syntax such as
# v = u + [5, 3, 10, −2, 1], in which the sum of a vector and list returns
# a new vector. However, the syntax v = [5, 3, 10, −2, 1] + u is illegal.
# Explain how the Vector class definition can be revised so that this syntax
# generates a new vector.

# %% [markdown]
# #R-2.11
#
# The Vector class definition can be revised by adding an additional "__ add __ method which performs the same calculation as the existing __ add __ method but with the parameters reversed. This would allow for the v = [5, 3, 10, −2, 1] + u syntax to generate a new vector.

# %% [markdown]
# Implement the mul method for the Vector class of Section 2.3.3, so
# that the expression v 3 returns a new vector with coordinates that are 3
# times the respective coordinates of v.

# %%
#R-2.12

class Vector:
    def __init__(self, d):
        if isinstance(d, int):
            self._coords = [0] * d
        else:
            try:
                self._coords = [val for val in d]
            except TypeError:
                raise TypeError('invalid parameter type')

    def __len__(self):
        return len(self._coords)

    def __getitem__(self, j):
        return self._coords[j]

    def __setitem__(self, j, val):
        self._coords[j] = val

    def __add__(self, other):
        if len(self) != len(other):
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] + other[j]
        return result

    def __sub__(self, other):
        if len(self) != len(other):
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] - other[j]
        return result

    def __eq__(self, other):
        return self._coords == other._coords

    def __ne__(self, other):
        return not self == other

    def __str__(self):
        return '<' + str(self._coords)[1:-1] + '>'

    def __mul__(self, other):  # multiply by a scalar
        if isinstance(other, int) or isinstance(other, float):
            result = Vector(len(self))
            for j in range(len(self)):
                result[j] = self[j] * other
            return result

        else:
            raise TypeError('invalid parameter type')

# %% [markdown]
# Exercise R-2.12 asks for an implementation of mul , for the Vector
# class of Section 2.3.3, to provide support for the syntax v 3. Implement
# the rmul method, to provide additional support for syntax 3 v

# %%
#R-2.13

class Vector:
    def __init__(self, d):
        if isinstance(d, int):
            self._coords = [0] * d
        else:
            try:
                self._coords = [val for val in d]
            except TypeError:
                raise TypeError('invalid parameter type')

    def __len__(self):
        return len(self._coords)

    def __getitem__(self, j):
        return self._coords[j]

    def __setitem__(self, j, val):
        self._coords[j] = val

    def __add__(self, other):
        if len(self) != len(other):
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] + other[j]
        return result

    def __sub__(self, other):
        if len(self) != len(other):
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] - other[j]
        return result

    def __eq__(self, other):
        return self._coords == other._coords

    def __ne__(self, other):
        return not self == other

    def __str__(self):
        return '<' + str(self._coords)[1:-1] + '>'

    def __mul__(self, other):  # multiply by a scalar
        if isinstance(other, int) or isinstance(other, float):
            result = Vector(len(self))
            for j in range(len(self)):
                result[j] = self[j] * other
            return result

        else:
            raise TypeError('invalid parameter type')

    def __rmul__(self, other):  # multiply by a scalar
        if isinstance(other, int) or isinstance(other, float):
            result = Vector(len(self))
            for j in range(len(self)):
                result[j] = self[j] * other
            return result

        else:
            raise TypeError('invalid parameter type')

# %% [markdown]
# Implement the mul method for the Vector class of Section 2.3.3, so
# that the expression u v returns a scalar that represents the dot product of
# the vectors.

# %%
#R-2.14

class Vector:
    def __init__(self, d):
        self._coords = [0] * d

    def __len__(self):
        return len(self._coords)

    def __getitem__(self, j):
        return self._coords[j]

    def __setitem__(self, j, val):
        self._coords[j] = val

    def __add__(self, other):
        if len(self) != len(other):
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] + other[j]
        return result

    def __sub__(self, other):
        if len(self) != len(other):
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] - other[j]
        return result

    def __mul__(self, other):
        if len(self) != len(other):
            raise ValueError('dimensions must agree')
        result = 0
        for j in range(len(self)):
            result += self[j] * other[j]
        return result

    def __ne__(self, other):
        return not self == other

    def __neg__(self):
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = -self[j]
        return result

    def __eq__(self, other):
        return self._coords == other._coords

    def __str__(self):
        return '<' + str(self._coords)[1:-1] + '>'

# %% [markdown]
# The Vector class of Section 2.3.3 provides a constructor that takes an integer d, and produces a d-dimensional vector with all coordinates equal to
# 0. Another convenient form for creating a new vector would be to send the
# constructor a parameter that is some iterable type representing a sequence
# of numbers, and to create a vector with dimension equal to the length of
# that sequence and coordinates equal to the sequence values. For example,
# Vector([4, 7, 5]) would produce a three-dimensional vector with coordinates <4, 7, 5>. Modify the constructor so that either of these forms is
# acceptable; that is, if a single integer is sent, it produces a vector of that
# dimension with all zeros, but if a sequence of numbers is provided, it produces a vector with coordinates based on that sequence.

# %%
#R-2.15

class Vector:
    """Represent a vector in a multidimensional space."""

    def __init__(self, d):
        """Create d-dimensional vector of zeros."""
        if isinstance(d, int):
            self._coords = [0] * d
        else:
            try:
                self._coords = [val for val in d]
            except TypeError:
                raise TypeError('The argument must be an int or an iterable')

    def __len__(self):
        """Return the dimension of the vector."""
        return len(self._coords)

    def __getitem__(self, j):
        """Return jth coordinate of vector."""
        return self._coords[j]

    def __setitem__(self, j, val):
        """Set jth coordinate of vector to given value."""
        self._coords[j] = val

    def __add__(self, other):
        """Return sum of two vectors."""
        if len(self) != len(other):
            # relies on len method
            raise ValueError('dimensions must agree')
        result = Vector(len(self))
        for j in range(len(self)):
            result[j] = self[j] + other[j]
        return result

    def __eq__(self, other):
        """Return True if vector has same coordinates as other."""
        return self._coords == other._coords

    def __ne__(self, other):
        """Return True if vector differs from other."""
        return not self == other

    def __str__(self):
        """Produce string representation of vector."""
        return '<' + str(self._coords)[1:-1] + '>'

# %% [markdown]
# Our Range class, from Section 2.3.5, relies on the formula
# max(0, (stop − start + step − 1) // step)
# to compute the number of elements in the range. It is not immediately evident why this formula provides the correct calculation, even if assuming
# a positive step size. Justify this formula, in your own words

# %% [markdown]
# #R-2.16
#
# This formula provides the correct calculation for the number of elements in a range because it finds the total number of 'spaces' between the start and stop values, then divides the number of 'spaces' by the step size. The result of the division is the number of elements in the range. The max(0, ...) ensures that the value returned is not negative, since a range cannot have a negative number of elements.

# %% [markdown]
# Draw a class inheritance diagram for the following set of classes:
#
# • Class Goat extends object and adds an instance variable tail and
# methods milk( ) and jump( ).
#
# • Class Pig extends object and adds an instance variable nose and
# methods eat(food) and wallow( ).
#
# • Class Horse extends object and adds instance variables height and
# color, and methods run( ) and jump( ).
#
# • Class Racer extends Horse and adds a method race( ).
#
# • Class Equestrian extends Horse, adding an instance variable weight
# and methods trot( ) and is trained( )

# %%
#R-2.17

"""
Object
  |
  |
  |--Goat
  |     |
  |     |--tail
  |     |--milk()
  |     |--jump()
  |
  |--Pig
  |     |
  |     |--nose
  |     |--eat(food)
  |     |--wallow()
  |
  |--Horse
  |      |
  |      |--height
  |      |--color
  |      |--run()
  |      |--jump()
  |
  |--Racer (extends Horse)
  |      |
  |      |--race()
  |
  |--Equestrian (extends Horse)
  |      |
  |      |--weight
  |      |--trot()
  |      |--isTrained()
  
  """

# %% [markdown]
# Give a short fragment of Python code that uses the progression classes
# from Section 2.4.2 to find the 8th value of a Fibonacci progression that
# starts with 2 and 2 as its first two values.

# %%
#R-2.18

"""
fib_prog = Progression(2, 2)
print(fib_prog[7])

"""

# %% [markdown]
# When using the ArithmeticProgression class of Section 2.4.2 with an increment of 128 and a start of 0, how many calls to next can we make
# before we reach an integer of 263 or larger?

# %% [markdown]
# #R-2.19
#
# We can make 63 calls to next before we reach an integer of 2^63 or larger.

# %% [markdown]
# What are some potential efficiency disadvantages of having very deep inheritance trees, that is, a large set of classes, A, B, C, and so on, such that
# B extends A, C extends B, D extends C, etc.?

# %% [markdown]
# #R-2.20
#
# 1. Increased complexity: With deeper inheritance trees, there is more complexity in understanding the class relationships and how they interact with each other. This can make it difficult to debug, maintain, and extend code.
#
# 2. Increased development time: Since there is more complexity involved in understanding the class relationships, it can take longer to develop and test code.
#
# 3. Increased memory usage: Deep inheritance trees can lead to increased memory usage as each class has to store its own data, as well as the data of its parent classes.
#
# 4. Reduced flexibility: With deep inheritance trees, it can be difficult to modify existing classes and add new features, as this could have an effect on other classes down the inheritance tree.
#
# 5. Reduced performance: As the inheritance tree gets deeper, there will be an increase in the number of calls to parent classes, which can lead to reduced performance.

# %% [markdown]
# What are some potential efficiency disadvantages of having very shallow
# inheritance trees, that is, a large set of classes, A, B, C, and so on, such
# that all of these classes extend a single class, Z?

# %% [markdown]
# #R-2.21
#
# 1. Code duplication: when all classes share the same parent class, much of the code in each class may be the same as the other classes, resulting in unnecessary duplication.
#
# 2. Difficulty in debugging: when all classes share the same parent class, it can be difficult to trace the source of errors and bugs.
#
# 3. Lack of code reusability: when all classes share the same parent class, little code is shared between classes, making it difficult to reuse code.
#
# 4. Poor organization and readability: when all classes share the same parent class, the code can become difficult to read and organize. This can increase the time it takes to debug and maintain the code.

# %% [markdown]
# The collections.Sequence abstract base class does not provide support for
# comparing two sequences to each other. Modify our Sequence class from
# Code Fragment 2.14 to include a definition for the eq method, so
# that expression seq1 == seq2 will return True precisely when the two
# sequences are element by element equivalent.

# %%
#R-2.22

class Sequence:
    """Our own version of a collection.Sequence abstract base class."""

    def __len__(self):
        """Return the length of the sequence."""
        return self._len

    def __getitem__(self, j):
        """Return the element at index j of the sequence."""
        if j < 0 or j >= self._len:
            raise IndexError('index out of range')
        return self._data[j]

    def __eq__(self, other):
        """Return True if the two sequences have the same elements in
        the same order."""
        if self._len != len(other):
            return False
        for j in range(self._len):
            if self[j] != other[j]:
                return False
        return True

    def __contains__(self, value):
        """Return True if value is found in the sequence."""
        for j in range(self._len):
            if self[j] == value:  # found match
                return True
        return False  # no match

# %% [markdown]
# In similar spirit to the previous problem, augment the Sequence class with
# method lt , to support lexicographic comparison seq1 < seq2.

# %%
#R-2.23

class Sequence:
    """Our own version of a collection.Sequence abstract base class."""

    def __len__(self):
        """Return the length of the sequence."""
        return self._len

    def __getitem__(self, j):
        """Return the element at index j of the sequence."""
        if j < 0 or j >= self._len:
            raise IndexError('index out of range')
        return self._data[j]

    def __eq__(self, other):
        """Return True if the two sequences have the same elements in
        the same order."""
        if self._len != len(other):
            return False
        for j in range(self._len):
            if self[j] != other[j]:
                return False
        return True

    def __lt__(self, other):
        """Return True if the sequence self is lexicographically
        less than other."""
        for j in range(min(self._len, len(other))):
            if self[j] < other[j]:  # self is shorter than other
                return True
            elif self[j] > other[j]:  # self is longer than other
                return False
        return self._len < len(other)  # same length, check size

    def __contains__(self, value):
        """Return True if value is found in the sequence."""
        for j in range(self._len):
            if self[j] == value:  # found match
                return True
        return False  # no match
